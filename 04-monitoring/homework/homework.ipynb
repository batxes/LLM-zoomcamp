# %%
import pandas as pd
from tqdm import tqdm
from sentence_transformers import SentenceTransformer
import numpy as np


github_url = "https://github.com/DataTalksClub/llm-zoomcamp/blob/main/04-monitoring/data/results-gpt4o-mini.csv"
model_name = "multi-qa-mpnet-base-dot-v1"

# %%
url = f'{github_url}?raw=1'
df = pd.read_csv(url)

# %%
df
# Out:
#                                              answer_llm  \
# 0     You can sign up for the course by visiting the...
# 1     You can sign up using the link provided in the...
# 2     Yes, there is an FAQ for the Machine Learning ...
# 3     The context does not provide any specific info...
# 4     To structure your questions and answers for th...
# ...                                                 ...
# 1825  Some suggested titles for listing the Machine ...
# 1826  It is best advised that you do not list the Ma...
# 1827  You can incorporate your Machine Learning Zoom...
# 1828  The advice on including a project link in a CV...
# 1829  The suggestion to showcase progress through Li...
#
#                                             answer_orig  document  \
# 0     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 1     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 2     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 3     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 4     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# ...                                                 ...       ...
# 1825  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1826  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1827  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1828  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1829  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
#
#                                                question  \
# 0                   Where can I sign up for the course?
# 1                    Can you provide a link to sign up?
# 2     Is there an FAQ for this Machine Learning course?
# 3     Does this course have a GitHub repository for ...
# 4     How can I structure my questions and answers f...
# ...                                                 ...
# 1825  What are some suggested titles for listing the...
# 1826  Should I list the Machine Learning Zoomcamp ex...
# 1827  In which LinkedIn sections can I incorporate m...
# 1828  Who gave advice on including a project link in...
# 1829  Who suggested showcasing progress through Link...
#
#                          course
# 0     machine-learning-zoomcamp
# 1     machine-learning-zoomcamp
# 2     machine-learning-zoomcamp
# 3     machine-learning-zoomcamp
# 4     machine-learning-zoomcamp
# ...                         ...
# 1825  machine-learning-zoomcamp
# 1826  machine-learning-zoomcamp
# 1827  machine-learning-zoomcamp
# 1828  machine-learning-zoomcamp
# 1829  machine-learning-zoomcamp
#
# [1830 rows x 5 columns]

# %% [markdown]
# ## Q1: Getting the embeddings model: What's the first value of the resulting vector?

# %%
embedding_model = SentenceTransformer(model_name)

# %%
answer_llm = df.iloc[0].answer_llm

# %%
answer_llm
# Out:
# 'You can sign up for the course by visiting the course page at [http://mlzoomcamp.com/](http://mlzoomcamp.com/).'

# %%
embeddings = embedding_model.encode(answer_llm)
first_value = embeddings[0]
print(first_value)
# Out:
# -0.4224468

# %% [markdown]
# ## Q2 Computing the dot product: What's the 75% percentile of the score?

# %%
results = df.to_dict(orient='records')

# %%
def compute_dot_product(record):
    answer_orig = record['answer_orig']
    answer_llm = record['answer_llm']
    
    v_llm = embedding_model.encode(answer_llm)
    v_orig = embedding_model.encode(answer_orig)
    
    return v_llm.dot(v_orig)

# %%
evaluations = []

for record in tqdm(results):
    sim = compute_dot_product(record)
    evaluations.append(sim)
# Out:
# 100%|█████████████████████████████████████████████████████| 1830/1830 [10:16<00:00,  2.97it/s]

# %%
print (np.median(evaluations))
# Out:
# 28.897568

# %%
print (np.percentile(evaluations,75))
# Out:
# 32.38979244232178

# %%
df["dot_product"] = evaluations

# %%
df["dot_product"].describe()
# Out:
# count    1830.000000
# mean       28.015770
# std         6.413297
# min         3.511809
# 25%        24.631172
# 50%        28.897568
# 75%        32.389792
# max        44.296776
# Name: dot_product, dtype: float64

# %% [markdown]
# ## Q3. Computing the cosine: What's the 75% cosine in the scores?

# %%
def normalize(v):
    norm = np.sqrt((v * v).sum())
    v_norm = v / norm
    return v_norm

# %%
def compute_dot_product_normalized(record):
    answer_orig = record['answer_orig']
    answer_llm = record['answer_llm']
    
    v_llm = normalize(embedding_model.encode(answer_llm))
    v_orig = normalize(embedding_model.encode(answer_orig))
    
    return v_llm.dot(v_orig)

# %%
normalized_evaluations = []

for record in tqdm(results):
    sim = compute_dot_product_normalized(record)
    normalized_evaluations.append(sim)
# Out:
# 100%|█████████████████████████████████████████████████████| 1830/1830 [10:10<00:00,  3.00it/s]

# %%
print (np.percentile(normalized_evaluations,75))
# Out:
# 0.8531119078397751

# %% [markdown]
# ## Q4. Rouge: What's the F score for rouge-1?

# %%
from rouge import Rouge

# %%
rouge_scorer = Rouge()

# %%
def compute_rouge(record):
    answer_orig = record['answer_orig']
    answer_llm = record['answer_llm']
    
    scores = rouge_scorer.get_scores(answer_orig, answer_llm)[0]
    return scores["rouge-1"]["f"]

# %%
rouge_fscore_evaluations = []

for record in tqdm(results):
    sim = compute_rouge(record)
    rouge_fscore_evaluations.append(sim)
# Out:
# 100%|████████████████████████████████████████████████████| 1830/1830 [00:02<00:00, 689.30it/s]

# %%
rouge_fscore_evaluations
# Out:
# [0.09523809178130524,
#  0.12499999641113292,
#  0.41558441095631643,
#  0.2162162117421476,
#  0.14207649881095297,
#  0.43137254522106894,
#  0.41269840791131274,
#  0.30434782321361065,
#  0.5172413747919143,
#  0.34374999517578125,
#  0.45454544954545456,
#  0.6060606010606061,
#  0.753623183415249,
#  0.7297297247881666,
#  0.6849315018952901,
#  0.4772727222727273,
#  0.47999999515022235,
#  0.3888888841358025,
#  0.2857142807256236,
#  0.37499999505,
#  0.24719100710011369,
#  0.2682926793664485,
#  0.5242718399095109,
#  0.18918918665814466,
#  0.5048543641813555,
#  0.6206896501724138,
#  0.3333333290589569,
#  0.4130434736011342,
#  0.633663361446917,
#  0.359550557257922,
#  0.4489795870054144,
#  0.5217391255198489,
#  0.4090909041322315,
#  0.25714285306122453,
#  0.16666666172839517,
#  0.19999999601250007,
#  0.29999999601250005,
#  0.42857142429705225,
#  0.23255813514332083,
#  0.7096774143756504,
#  0.4848484798530762,
#  0.3934426180166622,
#  0.5245901590002687,
#  0.3692307642414202,
#  0.22222221852839513,
#  0.11111110797839514,
#  0.15789473383656513,
#  0.09999999711250009,
#  0.054054050986121434,
#  0.09302325308815583,
#  0.44897958683696615,
#  0.48951048451269014,
#  0.23943661472227742,
#  0.4339622598629406,
#  0.41269840782438905,
#  0.6578947318732687,
#  0.45614034683902743,
#  0.5499999950031251,
#  0.3529411716825259,
#  0.31884057488762874,
#  0.04878048411659754,
#  0.2033898276931916,
#  0.2926829223319453,
#  0.36666666171666673,
#  0.22727272253099182,
#  0.0869565175047261,
#  0.06249999658203144,
#  0.2727272683884298,
#  0.07142856767857161,
#  0.09999999545000023,
#  0.2978723356518787,
#  0.36893203389197854,
#  0.3265306073781758,
#  0.3265306073781758,
#  0.2926829225907198,
#  0.5373134278369348,
#  0.5899280525666375,
#  0.4403669676996886,
#  0.47999999501567997,
#  0.42307691843934914,
#  0.16766466565886207,
#  0.3421052582003117,
#  0.1764705834785901,
#  0.3243243205519033,
#  0.29357797801868535,
#  0.4285714235827665,
#  0.3541666617013889,
#  0.4324324276113952,
#  0.47499999505000007,
#  0.36842104775623274,
#  0.15789473187326888,
#  0.46376811106910315,
#  0.5964912230717143,
#  0.4057970965763496,
#  0.33333332836076823,
#  0.4545454496189165,
#  0.7804877998899465,
#  0.4745762672335536,
#  0.4883720880232558,
#  0.3999999959388889,
#  0.5957446758872794,
#  0.5569620204518507,
#  0.5599999952568889,
#  0.47999999525688897,
#  0.39080459271766416,
#  0.42105262658393355,
#  0.5714285665755102,
#  0.4494381977073602,
#  0.33802816418171,
#  0.47191010781971976,
#  0.47524751986275854,
#  0.39370078241676487,
#  ...]

# %%
df["rouge"] = rouge_fscore_evaluations
df["rouge"].describe()
# Out:
# count    1830.000000
# mean        0.351695
# std         0.158905
# min         0.000000
# 25%         0.238887
# 50%         0.356300
# 75%         0.460133
# max         0.950000
# Name: rouge, dtype: float64

# %%
df[df.document == "5170565b"]
# Out:
#                                            answer_llm  \
# 10  Yes, all sessions are recorded, so if you miss...
# 11  Yes, you can ask your questions in advance if ...
# 12  If you miss a session, don't worry! Everything...
# 13  Yes, there is a way to catch up on a missed se...
# 14  Yes, you can still interact with instructors a...
#
#                                           answer_orig  document  \
# 10  Everything is recorded, so you won’t miss anyt...  5170565b
# 11  Everything is recorded, so you won’t miss anyt...  5170565b
# 12  Everything is recorded, so you won’t miss anyt...  5170565b
# 13  Everything is recorded, so you won’t miss anyt...  5170565b
# 14  Everything is recorded, so you won’t miss anyt...  5170565b
#
#                                              question  \
# 10               Are sessions recorded if I miss one?
# 11  Can I ask questions in advance if I can't atte...
# 12  How will my questions be addressed if I miss a...
# 13    Is there a way to catch up on a missed session?
# 14  Can I still interact with instructors after mi...
#
#                        course  dot_product     rouge
# 10  machine-learning-zoomcamp    32.344711  0.454545
# 11  machine-learning-zoomcamp    31.441839  0.606061
# 12  machine-learning-zoomcamp    36.380722  0.753623
# 13  machine-learning-zoomcamp    33.340508  0.729730
# 14  machine-learning-zoomcamp    30.606165  0.684932

# %% [markdown]
# ## Q5. Average rouge score

# %%
idx10 = df.iloc[10]

# %%
idx10["answer_orig"]
# Out:
# 'Everything is recorded, so you won’t miss anything. You will be able to ask your questions for office hours in advance and we will cover them during the live stream. Also, you can always ask questions in Slack.'

# %%
score_idx10 = rouge_scorer.get_scores(idx10["answer_orig"], idx10["answer_llm"])[0]
print (score_idx10["rouge-1"]["f"])
print (score_idx10["rouge-2"]["f"])
print (score_idx10["rouge-l"]["f"])
print ((score_idx10["rouge-1"]["f"]+score_idx10["rouge-2"]["f"]+score_idx10["rouge-l"]["f"])/3)
# Out:
# 0.45454544954545456
# 0.21621621121621637
# 0.42424241924242434
# 0.36500136000136507

# %% [markdown]
# ## Q6. Average rouge score for all data points

# %%
def compute_all_rouge(record):
    answer_orig = record['answer_orig']
    answer_llm = record['answer_llm']
    
    scores = rouge_scorer.get_scores(answer_orig, answer_llm)[0]
    return scores["rouge-2"]["f"]

# %%
rouge_fscore_2_evaluations = []

for record in tqdm(results):
    sim = compute_all_rouge(record)
    rouge_fscore_2_evaluations.append(sim)
# Out:
# 100%|████████████████████████████████████████████████████| 1830/1830 [00:02<00:00, 730.81it/s]

# %%
df["rouge-2"] = rouge_fscore_2_evaluations
df["rouge-2"].describe()
# Out:
# count    1830.000000
# mean        0.176717
# std         0.135790
# min         0.000000
# 25%         0.074074
# 50%         0.156993
# 75%         0.251150
# max         0.952381
# Name: rouge-2, dtype: float64

# %%
df
# Out:
#                                              answer_llm  \
# 0     You can sign up for the course by visiting the...
# 1     You can sign up using the link provided in the...
# 2     Yes, there is an FAQ for the Machine Learning ...
# 3     The context does not provide any specific info...
# 4     To structure your questions and answers for th...
# ...                                                 ...
# 1825  Some suggested titles for listing the Machine ...
# 1826  It is best advised that you do not list the Ma...
# 1827  You can incorporate your Machine Learning Zoom...
# 1828  The advice on including a project link in a CV...
# 1829  The suggestion to showcase progress through Li...
#
#                                             answer_orig  document  \
# 0     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 1     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 2     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 3     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 4     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# ...                                                 ...       ...
# 1825  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1826  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1827  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1828  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
# 1829  I’ve seen LinkedIn users list DataTalksClub as...  c6a22665
#
#                                                question  \
# 0                   Where can I sign up for the course?
# 1                    Can you provide a link to sign up?
# 2     Is there an FAQ for this Machine Learning course?
# 3     Does this course have a GitHub repository for ...
# 4     How can I structure my questions and answers f...
# ...                                                 ...
# 1825  What are some suggested titles for listing the...
# 1826  Should I list the Machine Learning Zoomcamp ex...
# 1827  In which LinkedIn sections can I incorporate m...
# 1828  Who gave advice on including a project link in...
# 1829  Who suggested showcasing progress through Link...
#
#                          course  dot_product     rouge   rouge-2
# 0     machine-learning-zoomcamp    17.515987  0.095238  0.095238
# 1     machine-learning-zoomcamp    13.418400  0.125000  0.125000
# 2     machine-learning-zoomcamp    25.313251  0.415584  0.415584
# 3     machine-learning-zoomcamp    12.147415  0.216216  0.216216
# 4     machine-learning-zoomcamp    18.747738  0.142076  0.142076
# ...                         ...          ...       ...       ...
# 1825  machine-learning-zoomcamp    34.590019  0.336134  0.336134
# 1826  machine-learning-zoomcamp    34.473343  0.453782  0.453782
# 1827  machine-learning-zoomcamp    35.101955  0.442748  0.442748
# 1828  machine-learning-zoomcamp    23.863712  0.191489  0.191489
# 1829  machine-learning-zoomcamp    23.946171  0.147368  0.147368
#
# [1830 rows x 8 columns]
